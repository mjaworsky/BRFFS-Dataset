# %%
import os
import pandas as pd

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np

import os
import pandas as pd

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_ML_nona.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (3520, 131)
# (3520, 129)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))

  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('LR True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='LR True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))

  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('MNB True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='MNB True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('LDA True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='LDA True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('RF True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='RF True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('KNN True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='KNN True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90       578
#            1       0.00      0.00      0.00       126
#
#     accuracy                           0.82       704
#    macro avg       0.41      0.50      0.45       704
# weighted avg       0.67      0.82      0.74       704
#
# Hamming Loss: 0.17897727272727273
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_ML_nona.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (3520, 131)
# (3520, 129)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
import numpy as np
from matplotlib import pyplot


a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
  
  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  ns_auc = roc_auc_score(y_test, ns_probs)
  lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  print('False Positive: ROC AUC=%.3f' % (ns_auc))
  print('SVM True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  pyplot.plot(lr_fpr, lr_tpr, marker='.', label='SVM True')
  # axis labels
  pyplot.xlabel('False Positive Rate')
  pyplot.ylabel('True Positive Rate')
  # show the legend
  pyplot.legend()
  # show the plot
  pyplot.show()
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90       578
#            1       0.00      0.00      0.00       126
#
#     accuracy                           0.82       704
#    macro avg       0.41      0.50      0.45       704
# weighted avg       0.67      0.82      0.74       704
#
# Hamming Loss: 0.17897727272727273
# False Positive: ROC AUC=0.500
# SVM True: ROC AUC=0.500
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
import os
import pandas as pd

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_ML_nona.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (3520, 131)
# (3520, 129)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from imblearn.ensemble import RUSBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.90       578
#            1       0.00      0.00      0.00       126
#
#     accuracy                           0.82       704
#    macro avg       0.41      0.50      0.45       704
# weighted avg       0.67      0.82      0.74       704
#
# Hamming Loss: 0.18323863636363635
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.83      0.99      0.90       584
#            1       0.12      0.01      0.02       120
#
#     accuracy                           0.82       704
#    macro avg       0.48      0.50      0.46       704
# weighted avg       0.71      0.82      0.75       704
#
# Hamming Loss: 0.17897727272727273
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
# ...

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_KGFS25.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (22053, 35)
# (22053, 33)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from imblearn.ensemble import RUSBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91      3679
#            1       0.00      0.00      0.00       732
#
#     accuracy                           0.83      4411
#    macro avg       0.42      0.50      0.45      4411
# weighted avg       0.70      0.83      0.76      4411
#
# Hamming Loss: 0.16980276581274087
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90      3717
#            1       0.00      0.00      0.00       694
#
#     accuracy                           0.82      4411
#    macro avg       0.42      0.49      0.45      4411
# weighted avg       0.71      0.82      0.76      4411
#
# Hamming Loss: 0.18000453411924733
# ...

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_ML_nona.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (3520, 131)
# (3520, 129)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np
from imblearn.over_sampling import SMOTE

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB(alpha=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, MissingDataFix - MultinomialNB + SMOTE")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-594d55cdbc0d> in <module>
#      24
#      25 oversample = SMOTE()
# ---> 26 X, y = oversample.fit_resample(X, y)
#      27
#      28 n_split=5
#
# ~\AppData\Roaming\Python\Python36\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      75         check_classification_targets(y)
#      76         arrays_transformer = ArraysTransformer(X, y)
# ---> 77         X, y, binarize_y = self._check_X_y(X, y)
#      78
#      79         self.sampling_strategy_ = check_sampling_strategy(
#
# ~\AppData\Roaming\Python\Python36\site-packages\imblearn\base.py in _check_X_y(self, X, y, accept_sparse)
#     127         if accept_sparse is None:
#     128             accept_sparse = ["csr", "csc"]
# --> 129         y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
# ...

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_ML_nona.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (3520, 131)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-e375ae843828> in <module>
#       9 print(BRFSS_Grounded.shape)
#      10
# ---> 11 BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)
#      12
#      13 print(BRFSS_Grounded_X.shape)
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# ...

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np
from imblearn.over_sampling import SMOTE

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90       578
#            1       0.00      0.00      0.00       126
#
#     accuracy                           0.82       704
#    macro avg       0.41      0.50      0.45       704
# weighted avg       0.67      0.82      0.74       704
#
# Hamming Loss: 0.17897727272727273
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_KGFS25.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np
from imblearn.over_sampling import SMOTE

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_KGFS25.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)

# %%
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model1 = MultinomialNB()
  model1 = OneVsRestClassifier(MultinomialNB())   
  clf1 = model1.fit(X_train, mlb.transform(y_train))

  y_pred = clf1.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test1 = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph FS - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test1, pred))

  hl=hamming_loss(y_test1,pred)
  print("Hamming Loss: " + str(hl))

  print("pred shape: " + str(pred.shape))
    
  #print(pred)

  model2 = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf2 = model2.fit(X_train, mlb.transform(y_train))

  y_pred2 = clf2.predict(X_test)  
  pred2 = np.argmax(y_pred2, axis=1)
  y_test2 = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph FS - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test2, pred2))

  hl2=hamming_loss(y_test2,pred2)
  print("Hamming Loss: " + str(hl2))
    
  print("pred2 shape: " + str(pred2.shape))

  #print(pred2)
    
  ensemble_pred = np.maximum(pred, pred2, out=pred)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph FS - Ensemble MultinomialNB + RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test2, ensemble_pred))

  hl2=hamming_loss(y_test2,ensemble_pred)
  print("Hamming Loss: " + str(hl2))
    
  print("ensemble_pred shape: " + str(ensemble_pred.shape))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-a59195ac21f6> in <module>
#       1 X = np.array(BRFSS_Grounded_X)
# ----> 2 y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()
#       3
#       4 n_split=5
#       5
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
# ...

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_ML_nona.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (3520, 131)
# (3520, 129)

# %%
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model1 = MultinomialNB()
  model1 = OneVsRestClassifier(MultinomialNB())   
  clf1 = model1.fit(X_train, mlb.transform(y_train))

  y_pred = clf1.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test1 = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph FS - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test1, pred))

  hl=hamming_loss(y_test1,pred)
  print("Hamming Loss: " + str(hl))

  print("pred shape: " + str(pred.shape))
    
  #print(pred)

  model2 = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf2 = model2.fit(X_train, mlb.transform(y_train))

  y_pred2 = clf2.predict(X_test)  
  pred2 = np.argmax(y_pred2, axis=1)
  y_test2 = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph FS - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test2, pred2))

  hl2=hamming_loss(y_test2,pred2)
  print("Hamming Loss: " + str(hl2))
    
  print("pred2 shape: " + str(pred2.shape))

  #print(pred2)
    
  ensemble_pred = np.maximum(pred, pred2, out=pred)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph FS - Ensemble MultinomialNB + RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test2, ensemble_pred))

  hl2=hamming_loss(y_test2,ensemble_pred)
  print("Hamming Loss: " + str(hl2))
    
  print("ensemble_pred shape: " + str(ensemble_pred.shape))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph FS - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.83      0.41      0.55       578
#            1       0.19      0.63      0.29       126
#
#     accuracy                           0.45       704
#    macro avg       0.51      0.52      0.42       704
# weighted avg       0.72      0.45      0.50       704
#
# Hamming Loss: 0.5525568181818182
# pred shape: (704,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph FS - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.90       578
#            1       0.00      0.00      0.00       126
#
#     accuracy                           0.82       704
#    macro avg       0.41      0.50      0.45       704
# weighted avg       0.67      0.82      0.74       704
#
# Hamming Loss: 0.18323863636363635
# pred2 shape: (704,)
# ...

# %%
import os
import pandas as pd
from imblearn.ensemble import RUSBoostClassifier

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_KGFS25.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (39590, 37)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-703afa81f278> in <module>
#      10 print(BRFSS_Grounded.shape)
#      11
# ---> 12 BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)
#      13
#      14 print(BRFSS_Grounded_X.shape)
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# ...

# %%
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model1 = MultinomialNB()
  model1 = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))  
  clf1 = model1.fit(X_train, mlb.transform(y_train))

  y_pred = clf1.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test1 = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test1, pred))

  hl=hamming_loss(y_test1,pred)
  print("Hamming Loss: " + str(hl))

  print("pred shape: " + str(pred.shape))
    
  #print(pred)

  model2 = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf2 = model2.fit(X_train, mlb.transform(y_train))

  y_pred2 = clf2.predict(X_test)  
  pred2 = np.argmax(y_pred2, axis=1)
  y_test2 = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test2, pred2))

  hl2=hamming_loss(y_test2,pred2)
  print("Hamming Loss: " + str(hl2))
    
  print("pred2 shape: " + str(pred2.shape))

  #print(pred2)
    
  ensemble_pred = np.maximum(pred, pred2, out=pred)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Ensemble Linear DA + RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test2, ensemble_pred))

  hl2=hamming_loss(y_test2,ensemble_pred)
  print("Hamming Loss: " + str(hl2))
    
  print("ensemble_pred shape: " + str(ensemble_pred.shape))

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_ML_nona.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (3520, 131)
# (3520, 129)

# %%
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model1 = MultinomialNB()
  model1 = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))  
  clf1 = model1.fit(X_train, mlb.transform(y_train))

  y_pred = clf1.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test1 = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test1, pred))

  hl=hamming_loss(y_test1,pred)
  print("Hamming Loss: " + str(hl))

  print("pred shape: " + str(pred.shape))
    
  #print(pred)

  model2 = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf2 = model2.fit(X_train, mlb.transform(y_train))

  y_pred2 = clf2.predict(X_test)  
  pred2 = np.argmax(y_pred2, axis=1)
  y_test2 = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test2, pred2))

  hl2=hamming_loss(y_test2,pred2)
  print("Hamming Loss: " + str(hl2))
    
  print("pred2 shape: " + str(pred2.shape))

  #print(pred2)
    
  ensemble_pred = np.maximum(pred, pred2, out=pred)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - Ensemble Linear DA + RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test2, ensemble_pred))

  hl2=hamming_loss(y_test2,ensemble_pred)
  print("Hamming Loss: " + str(hl2))
    
  print("ensemble_pred shape: " + str(ensemble_pred.shape))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90       578
#            1       0.33      0.01      0.02       126
#
#     accuracy                           0.82       704
#    macro avg       0.58      0.50      0.46       704
# weighted avg       0.73      0.82      0.74       704
#
# Hamming Loss: 0.18039772727272727
# pred shape: (704,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.90       578
#            1       0.00      0.00      0.00       126
#
#     accuracy                           0.82       704
#    macro avg       0.41      0.50      0.45       704
# weighted avg       0.67      0.82      0.74       704
#
# Hamming Loss: 0.18323863636363635
# pred2 shape: (704,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded - Ensemble Linear DA + RUSBoost
# ...

# %%
import os
import pandas as pd
from imblearn.ensemble import RUSBoostClassifier

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_KGFS25.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (39590, 37)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-703afa81f278> in <module>
#      10 print(BRFSS_Grounded.shape)
#      11
# ---> 12 BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)
#      13
#      14 print(BRFSS_Grounded_X.shape)
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# ...

# %%
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model1 = MultinomialNB()
  model1 = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))  
  clf1 = model1.fit(X_train, mlb.transform(y_train))

  y_pred = clf1.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test1 = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test1, pred))

  hl=hamming_loss(y_test1,pred)
  print("Hamming Loss: " + str(hl))

  print("pred shape: " + str(pred.shape))
    
  #print(pred)

  model2 = OneVsRestClassifier(MultinomialNB())   
  clf2 = model2.fit(X_train, mlb.transform(y_train))

  y_pred2 = clf2.predict(X_test)  
  pred2 = np.argmax(y_pred2, axis=1)
  y_test2 = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test2, pred2))

  hl2=hamming_loss(y_test2,pred2)
  print("Hamming Loss: " + str(hl2))
    
  print("pred2 shape: " + str(pred2.shape))

  #print(pred2)
    
  ensemble_pred = np.maximum(pred, pred2, out=pred)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Ensemble Linear DA + MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test2, ensemble_pred))

  hl2=hamming_loss(y_test2,ensemble_pred)
  print("Hamming Loss: " + str(hl2))
    
  print("ensemble_pred shape: " + str(ensemble_pred.shape))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-e2c2f55c1c93> in <module>
#       1 X = np.array(BRFSS_Grounded_X)
# ----> 2 y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()
#       3
#       4 n_split=5
#       5
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
# ...

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_ML_nona.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (3520, 131)
# (3520, 129)

# %%
 X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model1 = MultinomialNB()
  model1 = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))  
  clf1 = model1.fit(X_train, mlb.transform(y_train))

  y_pred = clf1.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test1 = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test1, pred))

  hl=hamming_loss(y_test1,pred)
  print("Hamming Loss: " + str(hl))

  print("pred shape: " + str(pred.shape))
    
  #print(pred)

  model2 = OneVsRestClassifier(MultinomialNB())   
  clf2 = model2.fit(X_train, mlb.transform(y_train))

  y_pred2 = clf2.predict(X_test)  
  pred2 = np.argmax(y_pred2, axis=1)
  y_test2 = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test2, pred2))

  hl2=hamming_loss(y_test2,pred2)
  print("Hamming Loss: " + str(hl2))
    
  print("pred2 shape: " + str(pred2.shape))

  #print(pred2)
    
  ensemble_pred = np.maximum(pred, pred2, out=pred)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Ensemble Linear DA + MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test2, ensemble_pred))

  hl2=hamming_loss(y_test2,ensemble_pred)
  print("Hamming Loss: " + str(hl2))
    
  print("ensemble_pred shape: " + str(ensemble_pred.shape))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90       578
#            1       0.33      0.01      0.02       126
#
#     accuracy                           0.82       704
#    macro avg       0.58      0.50      0.46       704
# weighted avg       0.73      0.82      0.74       704
#
# Hamming Loss: 0.18039772727272727
# pred shape: (704,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.83      0.41      0.55       578
#            1       0.19      0.63      0.29       126
#
#     accuracy                           0.45       704
#    macro avg       0.51      0.52      0.42       704
# weighted avg       0.72      0.45      0.50       704
#
# Hamming Loss: 0.5525568181818182
# ...

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_KGFS25_WCC.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (39590, 39)
# (39590, 37)

# %%
 from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))
    
#pred = np.argmax(y_pred, axis=1)
#y_test2 = np.argmax(y_test, axis=1)

#print(pred)
#print(y_test)

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7845
#            1       0.00      0.00      0.00        73
#
#     accuracy                           0.99      7918
#    macro avg       0.50      0.50      0.50      7918
# weighted avg       0.98      0.99      0.99      7918
#
# Hamming Loss: 0.009219499873705482
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
 from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np

    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Knowledge Graph-Based Feature Selection - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Knowledge Graph-Based Feature Selection - SVM
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7845
#            1       0.00      0.00      0.00        73
#
#     accuracy                           0.99      7918
#    macro avg       0.50      0.50      0.50      7918
# weighted avg       0.98      0.99      0.99      7918
#
# Hamming Loss: 0.009219499873705482
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
 from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from imblearn.ensemble import RUSBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.95      7845
#            1       0.01      0.10      0.02        73
#
#     accuracy                           0.91      7918
#    macro avg       0.50      0.51      0.49      7918
# weighted avg       0.98      0.91      0.94      7918
#
# Hamming Loss: 0.09042687547360445
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97      7843
#            1       0.01      0.08      0.03        75
#
#     accuracy                           0.94      7918
#    macro avg       0.50      0.51      0.50      7918
# weighted avg       0.98      0.94      0.96      7918
#
# Hamming Loss: 0.058853245769133616
# ...

# %%
 from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np
from imblearn.over_sampling import SMOTE

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7845
#            1       0.00      0.00      0.00        73
#
#     accuracy                           0.99      7918
#    macro avg       0.50      0.50      0.50      7918
# weighted avg       0.98      0.99      0.99      7918
#
# Hamming Loss: 0.009219499873705482
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
 from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np

import os
import pandas as pd

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_KGFS25.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (22053, 35)
# (22053, 33)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))

  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('LR True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='LR True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))

  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('MNB True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='MNB True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('LDA True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='LDA True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('RF True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='RF True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('KNN True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='KNN True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91      3679
#            1       0.00      0.00      0.00       732
#
#     accuracy                           0.83      4411
#    macro avg       0.42      0.50      0.45      4411
# weighted avg       0.70      0.83      0.76      4411
#
# Hamming Loss: 0.16980276581274087
# BRFSS MultiLabel Cancer + Diabetes - Grounded - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90      3717
#            1       0.00      0.00      0.00       694
#
#     accuracy                           0.82      4411
#    macro avg       0.42      0.49      0.45      4411
# weighted avg       0.71      0.82      0.76      4411
#
# Hamming Loss: 0.18000453411924733
# BRFSS MultiLabel Cancer + Diabetes - Grounded - Logistic Regression
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_KGFS50.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (12101, 57)
# (12101, 55)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))

  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('LR True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='LR True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))

  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('MNB True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='MNB True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('LDA True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='LDA True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('RF True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='RF True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('KNN True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='KNN True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.80      0.99      0.89      1946
#            1       0.00      0.00      0.00       475
#
#     accuracy                           0.80      2421
#    macro avg       0.40      0.50      0.44      2421
# weighted avg       0.65      0.80      0.71      2421
#
# Hamming Loss: 0.2023957042544403
# BRFSS MultiLabel Cancer + Diabetes - Grounded - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.81      0.97      0.88      1975
#            1       0.00      0.00      0.00       445
#
#     accuracy                           0.79      2420
#    macro avg       0.41      0.48      0.44      2420
# weighted avg       0.66      0.79      0.72      2420
#
# Hamming Loss: 0.21115702479338844
# BRFSS MultiLabel Cancer + Diabetes - Grounded - Logistic Regression
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2018XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2018XPT_Grounded_KGFS10.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE3'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (107235, 17)
# (107235, 15)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))

  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('LR True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='LR True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))

  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('MNB True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='MNB True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('LDA True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='LDA True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('RF True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='RF True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE3']].to_numpy()

n_split=5

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  ns_probs = [0 for _ in range(len(y_test))]
  lr_probs = y_pred[:, 1]

  #ns_auc = roc_auc_score(y_test, ns_probs)
  #lr_auc = roc_auc_score(y_test, lr_probs)
  # summarize scores
  #print('False Positive: ROC AUC=%.3f' % (ns_auc))
  #print('KNN True: ROC AUC=%.3f' % (lr_auc))
  # calculate roc curves
  #ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
  #lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
  # plot the roc curve for the model
  #pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='False')
  #pyplot.plot(lr_fpr, lr_tpr, marker='.', label='KNN True')
  # axis labels
  #pyplot.xlabel('False Positive Rate')
  #pyplot.ylabel('True Positive Rate')
  # show the legend
  #pyplot.legend()
  # show the plot
  #pyplot.show()
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     18221
#            1       0.93      0.03      0.05      3226
#
#     accuracy                           0.85     21447
#    macro avg       0.89      0.51      0.49     21447
# weighted avg       0.86      0.85      0.79     21447
#
# Hamming Loss: 0.1466405557886884
# BRFSS MultiLabel Cancer + Diabetes - Grounded - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     18537
#            1       0.58      0.00      0.00      2910
#
#     accuracy                           0.86     21447
#    macro avg       0.72      0.50      0.47     21447
# weighted avg       0.83      0.86      0.80     21447
#
# Hamming Loss: 0.13559005921574113
# BRFSS MultiLabel Cancer + Diabetes - Grounded - Logistic Regression
# ...
