# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_Grounded_KGFS25.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (66603, 20)
# (66603, 18)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)

print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     11807
#            1       0.00      0.00      0.00      1514
#
#     accuracy                           0.89     13321
#    macro avg       0.44      0.50      0.47     13321
# weighted avg       0.79      0.89      0.83     13321
#
# Hamming Loss: 0.11365513099617146
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     11391
#            1       0.00      0.00      0.00      1930
#
#     accuracy                           0.86     13321
#    macro avg       0.43      0.50      0.46     13321
# weighted avg       0.73      0.86      0.79     13321
#
# Hamming Loss: 0.14488401771638765
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     11181
#            1       0.00      0.00      0.00      2140
#
#     accuracy                           0.84     13321
#    macro avg       0.42      0.50      0.46     13321
# weighted avg       0.70      0.84      0.77     13321
#
# Hamming Loss: 0.16064859995495834
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     11456
#            1       0.00      0.00      0.00      1864
#
#     accuracy                           0.86     13320
#    macro avg       0.43      0.50      0.46     13320
# weighted avg       0.74      0.86      0.80     13320
#
# Hamming Loss: 0.13993993993993994
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     11712
#            1       0.00      0.00      0.00      1608
#
#     accuracy                           0.88     13320
#    macro avg       0.44      0.50      0.47     13320
# weighted avg       0.77      0.88      0.82     13320
#
# Hamming Loss: 0.12072072072072072
# y_pred shape:
# (13320, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     57547
#            1       0.00      0.00      0.00      9056
#
#     accuracy                           0.86     66603
#    macro avg       0.43      0.50      0.46     66603
# weighted avg       0.75      0.86      0.80     66603
#
# Hamming Loss: 0.13596968186563563
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     11807
#            1       0.00      0.00      0.00      1514
#
#     accuracy                           0.89     13321
#    macro avg       0.44      0.50      0.47     13321
# weighted avg       0.79      0.89      0.83     13321
#
# Hamming Loss: 0.11365513099617146
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     11391
#            1       0.00      0.00      0.00      1930
#
#     accuracy                           0.86     13321
#    macro avg       0.43      0.50      0.46     13321
# weighted avg       0.73      0.86      0.79     13321
#
# Hamming Loss: 0.14488401771638765
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85     11181
#            1       0.10      0.07      0.08      2140
#
#     accuracy                           0.75     13321
#    macro avg       0.47      0.47      0.47     13321
# weighted avg       0.71      0.75      0.73     13321
#
# Hamming Loss: 0.25335935740560017
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     11456
#            1       0.14      1.00      0.25      1864
#
#     accuracy                           0.14     13320
#    macro avg       0.07      0.50      0.12     13320
# weighted avg       0.02      0.14      0.03     13320
#
# Hamming Loss: 0.8600600600600601
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     11712
#            1       0.12      1.00      0.22      1608
#
#     accuracy                           0.12     13320
#    macro avg       0.06      0.50      0.11     13320
# weighted avg       0.01      0.12      0.03     13320
#
# Hamming Loss: 0.8792792792792793
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      0.57      0.69     57547
#            1       0.13      0.40      0.19      9056
#
#     accuracy                           0.55     66603
#    macro avg       0.49      0.49      0.44     66603
# weighted avg       0.76      0.55      0.62     66603
#
# Hamming Loss: 0.45024756909149977
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     11807
#            1       0.00      0.00      0.00      1514
#
#     accuracy                           0.89     13321
#    macro avg       0.44      0.50      0.47     13321
# weighted avg       0.79      0.89      0.83     13321
#
# Hamming Loss: 0.11365513099617146
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     11391
#            1       0.00      0.00      0.00      1930
#
#     accuracy                           0.86     13321
#    macro avg       0.43      0.50      0.46     13321
# weighted avg       0.73      0.86      0.79     13321
#
# Hamming Loss: 0.14488401771638765
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     11181
#            1       0.00      0.00      0.00      2140
#
#     accuracy                           0.84     13321
#    macro avg       0.42      0.50      0.46     13321
# weighted avg       0.70      0.84      0.77     13321
#
# Hamming Loss: 0.16064859995495834
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     11456
#            1       0.00      0.00      0.00      1864
#
#     accuracy                           0.86     13320
#    macro avg       0.43      0.50      0.46     13320
# weighted avg       0.74      0.86      0.80     13320
#
# Hamming Loss: 0.13993993993993994
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     11712
#            1       0.00      0.00      0.00      1608
#
#     accuracy                           0.88     13320
#    macro avg       0.44      0.50      0.47     13320
# weighted avg       0.77      0.88      0.82     13320
#
# Hamming Loss: 0.12072072072072072
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     57547
#            1       0.00      0.00      0.00      9056
#
#     accuracy                           0.86     66603
#    macro avg       0.43      0.50      0.46     66603
# weighted avg       0.75      0.86      0.80     66603
#
# Hamming Loss: 0.13596968186563563
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     11807
#            1       0.00      0.00      0.00      1514
#
#     accuracy                           0.89     13321
#    macro avg       0.44      0.50      0.47     13321
# weighted avg       0.79      0.89      0.83     13321
#
# Hamming Loss: 0.11365513099617146
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     11391
#            1       0.00      0.00      0.00      1930
#
#     accuracy                           0.86     13321
#    macro avg       0.43      0.50      0.46     13321
# weighted avg       0.73      0.86      0.79     13321
#
# Hamming Loss: 0.14488401771638765
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     11181
#            1       0.00      0.00      0.00      2140
#
#     accuracy                           0.84     13321
#    macro avg       0.42      0.50      0.46     13321
# weighted avg       0.70      0.84      0.77     13321
#
# Hamming Loss: 0.16064859995495834
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     11456
#            1       0.00      0.00      0.00      1864
#
#     accuracy                           0.86     13320
#    macro avg       0.43      0.50      0.46     13320
# weighted avg       0.74      0.86      0.80     13320
#
# Hamming Loss: 0.13993993993993994
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     11712
#            1       0.00      0.00      0.00      1608
#
#     accuracy                           0.88     13320
#    macro avg       0.44      0.50      0.47     13320
# weighted avg       0.77      0.88      0.82     13320
#
# Hamming Loss: 0.12072072072072072
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     57547
#            1       0.00      0.00      0.00      9056
#
#     accuracy                           0.86     66603
#    macro avg       0.43      0.50      0.46     66603
# weighted avg       0.75      0.86      0.80     66603
#
# Hamming Loss: 0.13596968186563563
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     11807
#            1       0.00      0.00      0.00      1514
#
#     accuracy                           0.89     13321
#    macro avg       0.44      0.50      0.47     13321
# weighted avg       0.79      0.89      0.83     13321
#
# Hamming Loss: 0.11365513099617146
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     11391
#            1       0.00      0.00      0.00      1930
#
#     accuracy                           0.86     13321
#    macro avg       0.43      0.50      0.46     13321
# weighted avg       0.73      0.86      0.79     13321
#
# Hamming Loss: 0.14488401771638765
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     11181
#            1       0.00      0.00      0.00      2140
#
#     accuracy                           0.84     13321
#    macro avg       0.42      0.50      0.46     13321
# weighted avg       0.70      0.84      0.77     13321
#
# Hamming Loss: 0.16064859995495834
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     11456
#            1       0.00      0.00      0.00      1864
#
#     accuracy                           0.86     13320
#    macro avg       0.43      0.50      0.46     13320
# weighted avg       0.74      0.86      0.80     13320
#
# Hamming Loss: 0.13993993993993994
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     11712
#            1       0.00      0.00      0.00      1608
#
#     accuracy                           0.88     13320
#    macro avg       0.44      0.50      0.47     13320
# weighted avg       0.77      0.88      0.82     13320
#
# Hamming Loss: 0.12072072072072072
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     57547
#            1       0.00      0.00      0.00      9056
#
#     accuracy                           0.86     66603
#    macro avg       0.43      0.50      0.46     66603
# weighted avg       0.75      0.86      0.80     66603
#
# Hamming Loss: 0.13596968186563563
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     11807
#            1       0.00      0.00      0.00      1514
#
#     accuracy                           0.89     13321
#    macro avg       0.44      0.50      0.47     13321
# weighted avg       0.79      0.89      0.83     13321
#
# Hamming Loss: 0.11365513099617146
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     11391
#            1       0.00      0.00      0.00      1930
#
#     accuracy                           0.86     13321
#    macro avg       0.43      0.50      0.46     13321
# weighted avg       0.73      0.86      0.79     13321
#
# Hamming Loss: 0.14488401771638765
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     11181
#            1       0.00      0.00      0.00      2140
#
#     accuracy                           0.84     13321
#    macro avg       0.42      0.50      0.46     13321
# weighted avg       0.70      0.84      0.77     13321
#
# Hamming Loss: 0.16064859995495834
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     11456
#            1       0.00      0.00      0.00      1864
#
#     accuracy                           0.86     13320
#    macro avg       0.43      0.50      0.46     13320
# weighted avg       0.74      0.86      0.80     13320
#
# Hamming Loss: 0.13993993993993994
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     11712
#            1       0.00      0.00      0.00      1608
#
#     accuracy                           0.88     13320
#    macro avg       0.44      0.50      0.47     13320
# weighted avg       0.77      0.88      0.82     13320
#
# Hamming Loss: 0.12072072072072072
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     57547
#            1       0.00      0.00      0.00      9056
#
#     accuracy                           0.86     66603
#    macro avg       0.43      0.50      0.46     66603
# weighted avg       0.75      0.86      0.80     66603
#
# Hamming Loss: 0.13596968186563563
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     11807
#            1       0.00      0.00      0.00      1514
#
#     accuracy                           0.89     13321
#    macro avg       0.44      0.50      0.47     13321
# weighted avg       0.79      0.89      0.83     13321
#
# Hamming Loss: 0.11365513099617146
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     11391
#            1       0.00      0.00      0.00      1930
#
#     accuracy                           0.86     13321
#    macro avg       0.43      0.50      0.46     13321
# weighted avg       0.73      0.86      0.79     13321
#
# Hamming Loss: 0.14488401771638765
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.89     11181
#            1       0.35      0.18      0.24      2140
#
#     accuracy                           0.81     13321
#    macro avg       0.60      0.56      0.57     13321
# weighted avg       0.77      0.81      0.79     13321
#
# Hamming Loss: 0.18512123714435852
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89     11456
#            1       0.27      0.25      0.26      1864
#
#     accuracy                           0.80     13320
#    macro avg       0.57      0.57      0.57     13320
# weighted avg       0.79      0.80      0.80     13320
#
# Hamming Loss: 0.1987237237237237
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     11712
#            1       0.00      0.00      0.00      1608
#
#     accuracy                           0.88     13320
#    macro avg       0.44      0.50      0.47     13320
# weighted avg       0.77      0.88      0.82     13320
#
# Hamming Loss: 0.12072072072072072
# y_pred shape:
# (13320, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92     57547
#            1       0.30      0.09      0.14      9056
#
#     accuracy                           0.85     66603
#    macro avg       0.59      0.53      0.53     66603
# weighted avg       0.79      0.85      0.81     66603
#
# Hamming Loss: 0.1526209660602724
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     11807
#            1       0.00      0.00      0.00      1514
#
#     accuracy                           0.89     13321
#    macro avg       0.44      0.50      0.47     13321
# weighted avg       0.79      0.89      0.83     13321
#
# Hamming Loss: 0.11365513099617146
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     11391
#            1       0.00      0.00      0.00      1930
#
#     accuracy                           0.86     13321
#    macro avg       0.43      0.50      0.46     13321
# weighted avg       0.73      0.86      0.79     13321
#
# Hamming Loss: 0.14488401771638765
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     11181
#            1       0.00      0.00      0.00      2140
#
#     accuracy                           0.84     13321
#    macro avg       0.42      0.50      0.46     13321
# weighted avg       0.70      0.84      0.77     13321
#
# Hamming Loss: 0.16064859995495834
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     11456
#            1       0.42      0.02      0.03      1864
#
#     accuracy                           0.86     13320
#    macro avg       0.64      0.51      0.48     13320
# weighted avg       0.80      0.86      0.80     13320
#
# Hamming Loss: 0.14091591591591593
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     11712
#            1       0.00      0.00      0.00      1608
#
#     accuracy                           0.88     13320
#    macro avg       0.44      0.50      0.47     13320
# weighted avg       0.77      0.88      0.82     13320
#
# Hamming Loss: 0.12072072072072072
# y_pred shape:
# (13320, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     57547
#            1       0.42      0.00      0.01      9056
#
#     accuracy                           0.86     66603
#    macro avg       0.64      0.50      0.47     66603
# weighted avg       0.80      0.86      0.80     66603
#
# Hamming Loss: 0.13616487706083083

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_Grounded_ML_nona.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (23265, 154)
# (23265, 152)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4099
#            1       0.00      0.00      0.00       554
#
#     accuracy                           0.88      4653
#    macro avg       0.44      0.50      0.47      4653
# weighted avg       0.78      0.88      0.83      4653
#
# Hamming Loss: 0.11906297012679991
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90      3776
#            1       1.00      0.00      0.00       877
#
#     accuracy                           0.81      4653
#    macro avg       0.91      0.50      0.45      4653
# weighted avg       0.85      0.81      0.73      4653
#
# Hamming Loss: 0.1882656350741457
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      3982
#            1       0.20      0.00      0.00       671
#
#     accuracy                           0.86      4653
#    macro avg       0.53      0.50      0.46      4653
# weighted avg       0.76      0.86      0.79      4653
#
# Hamming Loss: 0.1448527831506555
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.83      0.99      0.91      3856
#            1       0.38      0.02      0.03       797
#
#     accuracy                           0.83      4653
#    macro avg       0.61      0.51      0.47      4653
# weighted avg       0.75      0.83      0.76      4653
#
# Hamming Loss: 0.17300666236836448
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93      4092
#            1       0.06      0.00      0.00       561
#
#     accuracy                           0.88      4653
#    macro avg       0.47      0.50      0.47      4653
# weighted avg       0.78      0.88      0.82      4653
#
# Hamming Loss: 0.12357618740597465
# y_pred shape:
# (4653, 2)
# y_pred2 shape:
# (5, 4653, 2)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     19805
#            1       0.29      0.00      0.01      3460
#
#     accuracy                           0.85     23265
#    macro avg       0.57      0.50      0.46     23265
# weighted avg       0.77      0.85      0.78     23265
#
# Hamming Loss: 0.14975284762518806
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.88      0.51      0.65      4099
#            1       0.12      0.49      0.19       554
#
#     accuracy                           0.51      4653
#    macro avg       0.50      0.50      0.42      4653
# weighted avg       0.79      0.51      0.59      4653
#
# Hamming Loss: 0.49258542875564154
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.81      0.37      0.51      3776
#            1       0.19      0.64      0.29       877
#
#     accuracy                           0.42      4653
#    macro avg       0.50      0.50      0.40      4653
# weighted avg       0.70      0.42      0.47      4653
#
# Hamming Loss: 0.5815602836879432
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      0.43      0.58      3982
#            1       0.15      0.58      0.24       671
#
#     accuracy                           0.46      4653
#    macro avg       0.50      0.51      0.41      4653
# weighted avg       0.76      0.46      0.53      4653
#
# Hamming Loss: 0.5439501396948205
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.83      0.50      0.62      3856
#            1       0.17      0.49      0.25       797
#
#     accuracy                           0.50      4653
#    macro avg       0.50      0.50      0.44      4653
# weighted avg       0.71      0.50      0.56      4653
#
# Hamming Loss: 0.5003223726627982
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.87      0.18      0.29      4092
#            1       0.12      0.81      0.21       561
#
#     accuracy                           0.25      4653
#    macro avg       0.50      0.50      0.25      4653
# weighted avg       0.78      0.25      0.28      4653
#
# Hamming Loss: 0.7468300021491511
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.85      0.40      0.54     19805
#            1       0.15      0.60      0.24      3460
#
#     accuracy                           0.43     23265
#    macro avg       0.50      0.50      0.39     23265
# weighted avg       0.75      0.43      0.50     23265
#
# Hamming Loss: 0.573049645390071
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4099
#            1       0.00      0.00      0.00       554
#
#     accuracy                           0.88      4653
#    macro avg       0.44      0.50      0.47      4653
# weighted avg       0.78      0.88      0.82      4653
#
# Hamming Loss: 0.11992263056092843
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.81      0.99      0.89      3776
#            1       0.40      0.02      0.04       877
#
#     accuracy                           0.81      4653
#    macro avg       0.61      0.51      0.47      4653
# weighted avg       0.74      0.81      0.73      4653
#
# Hamming Loss: 0.190414786159467
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      3982
#            1       0.22      0.00      0.01       671
#
#     accuracy                           0.85      4653
#    macro avg       0.54      0.50      0.46      4653
# weighted avg       0.76      0.85      0.79      4653
#
# Hamming Loss: 0.14528261336771975
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.83      0.99      0.90      3856
#            1       0.36      0.02      0.03       797
#
#     accuracy                           0.83      4653
#    macro avg       0.60      0.50      0.47      4653
# weighted avg       0.75      0.83      0.75      4653
#
# Hamming Loss: 0.17322157747689662
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93      4092
#            1       0.18      0.02      0.03       561
#
#     accuracy                           0.87      4653
#    macro avg       0.53      0.50      0.48      4653
# weighted avg       0.80      0.87      0.82      4653
#
# Hamming Loss: 0.12722974425102085
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     19805
#            1       0.29      0.01      0.02      3460
#
#     accuracy                           0.85     23265
#    macro avg       0.57      0.50      0.47     23265
# weighted avg       0.77      0.85      0.78     23265
#
# Hamming Loss: 0.15121427036320653
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4099
#            1       0.00      0.00      0.00       554
#
#     accuracy                           0.88      4653
#    macro avg       0.44      0.50      0.47      4653
# weighted avg       0.78      0.88      0.83      4653
#
# Hamming Loss: 0.11906297012679991
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90      3776
#            1       0.00      0.00      0.00       877
#
#     accuracy                           0.81      4653
#    macro avg       0.41      0.50      0.45      4653
# weighted avg       0.66      0.81      0.73      4653
#
# Hamming Loss: 0.18848055018267784
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      3982
#            1       0.00      0.00      0.00       671
#
#     accuracy                           0.86      4653
#    macro avg       0.43      0.50      0.46      4653
# weighted avg       0.73      0.86      0.79      4653
#
# Hamming Loss: 0.14420803782505912
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91      3856
#            1       0.00      0.00      0.00       797
#
#     accuracy                           0.83      4653
#    macro avg       0.41      0.50      0.45      4653
# weighted avg       0.69      0.83      0.75      4653
#
# Hamming Loss: 0.17128734150010747
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4092
#            1       0.00      0.00      0.00       561
#
#     accuracy                           0.88      4653
#    macro avg       0.44      0.50      0.47      4653
# weighted avg       0.77      0.88      0.82      4653
#
# Hamming Loss: 0.12056737588652482
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     19805
#            1       0.00      0.00      0.00      3460
#
#     accuracy                           0.85     23265
#    macro avg       0.43      0.50      0.46     23265
# weighted avg       0.72      0.85      0.78     23265
#
# Hamming Loss: 0.1487212551042338
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4099
#            1       0.00      0.00      0.00       554
#
#     accuracy                           0.88      4653
#    macro avg       0.44      0.50      0.47      4653
# weighted avg       0.78      0.88      0.83      4653
#
# Hamming Loss: 0.11906297012679991
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90      3776
#            1       0.67      0.00      0.00       877
#
#     accuracy                           0.81      4653
#    macro avg       0.74      0.50      0.45      4653
# weighted avg       0.78      0.81      0.73      4653
#
# Hamming Loss: 0.1882656350741457
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      3982
#            1       0.00      0.00      0.00       671
#
#     accuracy                           0.86      4653
#    macro avg       0.43      0.50      0.46      4653
# weighted avg       0.73      0.86      0.79      4653
#
# Hamming Loss: 0.14442295293359123
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91      3856
#            1       0.11      0.00      0.00       797
#
#     accuracy                           0.83      4653
#    macro avg       0.47      0.50      0.45      4653
# weighted avg       0.71      0.83      0.75      4653
#
# Hamming Loss: 0.17279174725983237
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4092
#            1       0.00      0.00      0.00       561
#
#     accuracy                           0.88      4653
#    macro avg       0.44      0.50      0.47      4653
# weighted avg       0.77      0.88      0.82      4653
#
# Hamming Loss: 0.12056737588652482
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     19805
#            1       0.23      0.00      0.00      3460
#
#     accuracy                           0.85     23265
#    macro avg       0.54      0.50      0.46     23265
# weighted avg       0.76      0.85      0.78     23265
#
# Hamming Loss: 0.1490221362561788
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4099
#            1       0.00      0.00      0.00       554
#
#     accuracy                           0.88      4653
#    macro avg       0.44      0.50      0.47      4653
# weighted avg       0.78      0.88      0.83      4653
#
# Hamming Loss: 0.11906297012679991
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90      3776
#            1       0.00      0.00      0.00       877
#
#     accuracy                           0.81      4653
#    macro avg       0.41      0.50      0.45      4653
# weighted avg       0.66      0.81      0.73      4653
#
# Hamming Loss: 0.18848055018267784
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      3982
#            1       0.00      0.00      0.00       671
#
#     accuracy                           0.86      4653
#    macro avg       0.43      0.50      0.46      4653
# weighted avg       0.73      0.86      0.79      4653
#
# Hamming Loss: 0.14420803782505912
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91      3856
#            1       0.00      0.00      0.00       797
#
#     accuracy                           0.83      4653
#    macro avg       0.41      0.50      0.45      4653
# weighted avg       0.69      0.83      0.75      4653
#
# Hamming Loss: 0.17128734150010747
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4092
#            1       0.00      0.00      0.00       561
#
#     accuracy                           0.88      4653
#    macro avg       0.44      0.50      0.47      4653
# weighted avg       0.77      0.88      0.82      4653
#
# Hamming Loss: 0.12056737588652482
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     19805
#            1       0.00      0.00      0.00      3460
#
#     accuracy                           0.85     23265
#    macro avg       0.43      0.50      0.46     23265
# weighted avg       0.72      0.85      0.78     23265
#
# Hamming Loss: 0.1487212551042338
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4099
#            1       0.00      0.00      0.00       554
#
#     accuracy                           0.88      4653
#    macro avg       0.44      0.50      0.47      4653
# weighted avg       0.78      0.88      0.83      4653
#
# Hamming Loss: 0.11906297012679991
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      3776
#            1       0.41      0.32      0.36       877
#
#     accuracy                           0.79      4653
#    macro avg       0.63      0.61      0.62      4653
# weighted avg       0.77      0.79      0.78      4653
#
# Hamming Loss: 0.21362561788093704
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      3982
#            1       0.21      0.08      0.12       671
#
#     accuracy                           0.82      4653
#    macro avg       0.54      0.52      0.51      4653
# weighted avg       0.77      0.82      0.79      4653
#
# Hamming Loss: 0.17644530410487858
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      3856
#            1       0.28      0.08      0.12       797
#
#     accuracy                           0.81      4653
#    macro avg       0.56      0.52      0.51      4653
# weighted avg       0.74      0.81      0.76      4653
#
# Hamming Loss: 0.19363851278744895
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92      4092
#            1       0.21      0.06      0.09       561
#
#     accuracy                           0.86      4653
#    macro avg       0.55      0.51      0.51      4653
# weighted avg       0.80      0.86      0.82      4653
#
# Hamming Loss: 0.13905007522028798
# y_pred shape:
# (4653, 2)
# y_pred2 shape:
# (5, 4653, 2)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.91     19805
#            1       0.33      0.13      0.18      3460
#
#     accuracy                           0.83     23265
#    macro avg       0.60      0.54      0.54     23265
# weighted avg       0.78      0.83      0.80     23265
#
# Hamming Loss: 0.1683644960240705
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4099
#            1       0.00      0.00      0.00       554
#
#     accuracy                           0.88      4653
#    macro avg       0.44      0.50      0.47      4653
# weighted avg       0.78      0.88      0.83      4653
#
# Hamming Loss: 0.11906297012679991
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.90      3776
#            1       0.58      0.04      0.07       877
#
#     accuracy                           0.81      4653
#    macro avg       0.70      0.52      0.48      4653
# weighted avg       0.77      0.81      0.74      4653
#
# Hamming Loss: 0.18654631420588869
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      3982
#            1       0.00      0.00      0.00       671
#
#     accuracy                           0.86      4653
#    macro avg       0.43      0.50      0.46      4653
# weighted avg       0.73      0.86      0.79      4653
#
# Hamming Loss: 0.14420803782505912
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91      3856
#            1       0.25      0.00      0.00       797
#
#     accuracy                           0.83      4653
#    macro avg       0.54      0.50      0.46      4653
# weighted avg       0.73      0.83      0.75      4653
#
# Hamming Loss: 0.172147001934236
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4092
#            1       0.00      0.00      0.00       561
#
#     accuracy                           0.88      4653
#    macro avg       0.44      0.50      0.47      4653
# weighted avg       0.77      0.88      0.82      4653
#
# Hamming Loss: 0.12056737588652482
# y_pred shape:
# (4653, 2)
# y_pred2 shape:
# (5, 4653, 2)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     19805
#            1       0.54      0.01      0.02      3460
#
#     accuracy                           0.85     23265
#    macro avg       0.70      0.50      0.47     23265
# weighted avg       0.81      0.85      0.79     23265
#
# Hamming Loss: 0.14850633999570167
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_Grounded_KGFS10.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (168733, 7)
# (168733, 5)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93     29580
#            1       0.00      0.00      0.00      4167
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.77      0.88      0.82     33747
#
# Hamming Loss: 0.1234776424571073
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     29780
#            1       0.00      0.00      0.00      3967
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.78      0.88      0.83     33747
#
# Hamming Loss: 0.11755118973538388
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     29860
#            1       0.00      0.00      0.00      3887
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.78      0.88      0.83     33747
#
# Hamming Loss: 0.11518060864669452
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     29442
#            1       0.00      0.00      0.00      4304
#
#     accuracy                           0.87     33746
#    macro avg       0.44      0.50      0.47     33746
# weighted avg       0.76      0.87      0.81     33746
#
# Hamming Loss: 0.12754104190126236
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     30229
#            1       0.00      0.00      0.00      3517
#
#     accuracy                           0.90     33746
#    macro avg       0.45      0.50      0.47     33746
# weighted avg       0.80      0.90      0.85     33746
#
# Hamming Loss: 0.10421975937888935
# y_pred shape:
# (33746, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94    148891
#            1       0.00      0.00      0.00     19842
#
#     accuracy                           0.88    168733
#    macro avg       0.44      0.50      0.47    168733
# weighted avg       0.78      0.88      0.83    168733
#
# Hamming Loss: 0.11759404842386749
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93     29580
#            1       0.00      0.00      0.00      4167
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.77      0.88      0.82     33747
#
# Hamming Loss: 0.1234776424571073
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     29780
#            1       0.00      0.00      0.00      3967
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.78      0.88      0.83     33747
#
# Hamming Loss: 0.11755118973538388
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     29860
#            1       0.00      0.00      0.00      3887
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.78      0.88      0.83     33747
#
# Hamming Loss: 0.11518060864669452
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     29442
#            1       0.13      1.00      0.23      4304
#
#     accuracy                           0.13     33746
#    macro avg       0.06      0.50      0.11     33746
# weighted avg       0.02      0.13      0.03     33746
#
# Hamming Loss: 0.8724589580987376
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     30229
#            1       0.10      1.00      0.19      3517
#
#     accuracy                           0.10     33746
#    macro avg       0.05      0.50      0.09     33746
# weighted avg       0.01      0.10      0.02     33746
#
# Hamming Loss: 0.8957802406211106
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.88      0.60      0.71    148891
#            1       0.12      0.39      0.18     19842
#
#     accuracy                           0.58    168733
#    macro avg       0.50      0.50      0.45    168733
# weighted avg       0.79      0.58      0.65    168733
#
# Hamming Loss: 0.42488972791180685
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93     29580
#            1       0.00      0.00      0.00      4167
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.77      0.88      0.82     33747
#
# Hamming Loss: 0.1234776424571073
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     29780
#            1       0.00      0.00      0.00      3967
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.78      0.88      0.83     33747
#
# Hamming Loss: 0.11755118973538388
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     29860
#            1       0.00      0.00      0.00      3887
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.78      0.88      0.83     33747
#
# Hamming Loss: 0.11518060864669452
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     29442
#            1       0.00      0.00      0.00      4304
#
#     accuracy                           0.87     33746
#    macro avg       0.44      0.50      0.47     33746
# weighted avg       0.76      0.87      0.81     33746
#
# Hamming Loss: 0.12754104190126236
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     30229
#            1       0.00      0.00      0.00      3517
#
#     accuracy                           0.90     33746
#    macro avg       0.45      0.50      0.47     33746
# weighted avg       0.80      0.90      0.85     33746
#
# Hamming Loss: 0.10421975937888935
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94    148891
#            1       0.00      0.00      0.00     19842
#
#     accuracy                           0.88    168733
#    macro avg       0.44      0.50      0.47    168733
# weighted avg       0.78      0.88      0.83    168733
#
# Hamming Loss: 0.11759404842386749
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93     29580
#            1       0.00      0.00      0.00      4167
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.77      0.88      0.82     33747
#
# Hamming Loss: 0.1234776424571073
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     29780
#            1       0.00      0.00      0.00      3967
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.78      0.88      0.83     33747
#
# Hamming Loss: 0.11755118973538388
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     29860
#            1       0.00      0.00      0.00      3887
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.78      0.88      0.83     33747
#
# Hamming Loss: 0.11518060864669452
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     29442
#            1       0.00      0.00      0.00      4304
#
#     accuracy                           0.87     33746
#    macro avg       0.44      0.50      0.47     33746
# weighted avg       0.76      0.87      0.81     33746
#
# Hamming Loss: 0.12754104190126236
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     30229
#            1       0.00      0.00      0.00      3517
#
#     accuracy                           0.90     33746
#    macro avg       0.45      0.50      0.47     33746
# weighted avg       0.80      0.90      0.85     33746
#
# Hamming Loss: 0.10421975937888935
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94    148891
#            1       0.00      0.00      0.00     19842
#
#     accuracy                           0.88    168733
#    macro avg       0.44      0.50      0.47    168733
# weighted avg       0.78      0.88      0.83    168733
#
# Hamming Loss: 0.11759404842386749
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93     29580
#            1       0.00      0.00      0.00      4167
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.77      0.88      0.82     33747
#
# Hamming Loss: 0.1234776424571073
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     29780
#            1       0.00      0.00      0.00      3967
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.78      0.88      0.83     33747
#
# Hamming Loss: 0.11755118973538388
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     29860
#            1       0.00      0.00      0.00      3887
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.78      0.88      0.83     33747
#
# Hamming Loss: 0.11518060864669452
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     29442
#            1       0.00      0.00      0.00      4304
#
#     accuracy                           0.87     33746
#    macro avg       0.44      0.50      0.47     33746
# weighted avg       0.76      0.87      0.81     33746
#
# Hamming Loss: 0.12754104190126236
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     30229
#            1       0.00      0.00      0.00      3517
#
#     accuracy                           0.90     33746
#    macro avg       0.45      0.50      0.47     33746
# weighted avg       0.80      0.90      0.85     33746
#
# Hamming Loss: 0.10421975937888935
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94    148891
#            1       0.00      0.00      0.00     19842
#
#     accuracy                           0.88    168733
#    macro avg       0.44      0.50      0.47    168733
# weighted avg       0.78      0.88      0.83    168733
#
# Hamming Loss: 0.11759404842386749
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93     29580
#            1       0.00      0.00      0.00      4167
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.77      0.88      0.82     33747
#
# Hamming Loss: 0.1234776424571073
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     29780
#            1       0.00      0.00      0.00      3967
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.78      0.88      0.83     33747
#
# Hamming Loss: 0.11755118973538388
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     29860
#            1       0.00      0.00      0.00      3887
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.78      0.88      0.83     33747
#
# Hamming Loss: 0.11518060864669452
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     29442
#            1       0.00      0.00      0.00      4304
#
#     accuracy                           0.87     33746
#    macro avg       0.44      0.50      0.47     33746
# weighted avg       0.76      0.87      0.81     33746
#
# Hamming Loss: 0.12754104190126236
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     30229
#            1       0.00      0.00      0.00      3517
#
#     accuracy                           0.90     33746
#    macro avg       0.45      0.50      0.47     33746
# weighted avg       0.80      0.90      0.85     33746
#
# Hamming Loss: 0.10421975937888935
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94    148891
#            1       0.00      0.00      0.00     19842
#
#     accuracy                           0.88    168733
#    macro avg       0.44      0.50      0.47    168733
# weighted avg       0.78      0.88      0.83    168733
#
# Hamming Loss: 0.11759404842386749
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.91      0.06      0.11     29580
#            1       0.13      0.96      0.22      4167
#
#     accuracy                           0.17     33747
#    macro avg       0.52      0.51      0.16     33747
# weighted avg       0.81      0.17      0.12     33747
#
# Hamming Loss: 0.8313035232761431
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.92      0.05      0.10     29780
#            1       0.12      0.97      0.21      3967
#
#     accuracy                           0.16     33747
#    macro avg       0.52      0.51      0.16     33747
# weighted avg       0.83      0.16      0.11     33747
#
# Hamming Loss: 0.8399265119862507
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     29860
#            1       0.00      0.00      0.00      3887
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.78      0.88      0.83     33747
#
# Hamming Loss: 0.11518060864669452
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     29442
#            1       0.20      0.01      0.01      4304
#
#     accuracy                           0.87     33746
#    macro avg       0.54      0.50      0.47     33746
# weighted avg       0.79      0.87      0.81     33746
#
# Hamming Loss: 0.12952646239554316
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     30229
#            1       0.00      0.00      0.00      3517
#
#     accuracy                           0.90     33746
#    macro avg       0.45      0.50      0.47     33746
# weighted avg       0.80      0.90      0.85     33746
#
# Hamming Loss: 0.10421975937888935
# y_pred shape:
# (33746, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.89      0.62      0.73    148891
#            1       0.12      0.40      0.19     19842
#
#     accuracy                           0.60    168733
#    macro avg       0.50      0.51      0.46    168733
# weighted avg       0.80      0.60      0.67    168733
#
# Hamming Loss: 0.4040313731367042
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93     29580
#            1       0.00      0.00      0.00      4167
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.77      0.88      0.82     33747
#
# Hamming Loss: 0.1234776424571073
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     29780
#            1       0.00      0.00      0.00      3967
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.78      0.88      0.83     33747
#
# Hamming Loss: 0.11755118973538388
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     29860
#            1       0.00      0.00      0.00      3887
#
#     accuracy                           0.88     33747
#    macro avg       0.44      0.50      0.47     33747
# weighted avg       0.78      0.88      0.83     33747
#
# Hamming Loss: 0.11518060864669452
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     29442
#            1       0.00      0.00      0.00      4304
#
#     accuracy                           0.87     33746
#    macro avg       0.44      0.50      0.47     33746
# weighted avg       0.76      0.87      0.81     33746
#
# Hamming Loss: 0.12754104190126236
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     30229
#            1       0.00      0.00      0.00      3517
#
#     accuracy                           0.90     33746
#    macro avg       0.45      0.50      0.47     33746
# weighted avg       0.80      0.90      0.85     33746
#
# Hamming Loss: 0.10421975937888935
# y_pred shape:
# (33746, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94    148891
#            1       0.00      0.00      0.00     19842
#
#     accuracy                           0.88    168733
#    macro avg       0.44      0.50      0.47    168733
# weighted avg       0.78      0.88      0.83    168733
#
# Hamming Loss: 0.11759404842386749
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
