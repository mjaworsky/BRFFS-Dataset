# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt

# %%
G = nx.karate_club_graph()
color_map = []
for node in G:
    if node < 15:
        color_map.append('orange')
    else: 
        color_map.append('blue')      

nx.draw(G, node_color=color_map, with_labels=True)

plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
print(G)
# Out:
# Zachary's Karate Club

# %%
import spacy

#nlp = spacy.load('/opt/anaconda3/envs/NLPENV/lib/python3.7/site-packages/en_core_web_sm/en_core_web_sm-2.3.1')

import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
import networkx as nx
import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %%
import os

path = "C:\\Users\mdjaw\OneDrive\Documents\Markian Training\Research_USQ\TDA"

os.chdir( path )

kg_df = pd.read_csv("BRFSS_KG_top5.csv")

# %%
kg_df
# Out:
#      source  target  Word Count
# 0        19       1          18
# 1        19      11          26
# 2        19      12          23
# 3        19      13          31
# 4        19      16          15
# ..      ...     ...         ...
# 695     279     259           6
# 696     279     261          11
# 697     279     264           8
# 698     279     266          11
# 699     279     278          10
#
# [700 rows x 3 columns]

# %%
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)

color_map = []
for node in G:
    if node == 19:
        color_map.append('orange')
    elif node == 165:
        color_map.append('orange')
    elif node == 106:
        color_map.append('orange')
    elif node == 279:
        color_map.append('orange')
    elif node == 151:
        color_map.append('orange')
    else: 
        color_map.append('skyblue')      

#nx.draw(G, node_color=color_map, with_labels=True)

nx.draw(G, with_labels=True, node_color=color_map, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)

color_map = []
for node in G:
    if node == 19:
        color_map.append('orange')
    elif node == 165:
        color_map.append('orange')
    elif node == 106:
        color_map.append('orange')
    elif node == 279:
        color_map.append('orange')
    elif node == 151:
        color_map.append('orange')
    else: 
        color_map.append('skyblue')      

#nx.draw(G, node_color=color_map, with_labels=True)

nx.draw(G, with_labels=True, node_color=color_map, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
kg_df = pd.read_csv("ML_Diagram.csv")

# %%
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)

color_map = []
for node in G:
    if node == "Joint Multi-Label":
        color_map.append('orange')
    elif node == 165:
        color_map.append('orange')
    elif node == 106:
        color_map.append('orange')
    elif node == 279:
        color_map.append('orange')
    elif node == 151:
        color_map.append('orange')
    else: 
        color_map.append('skyblue')      

#nx.draw(G, node_color=color_map, with_labels=True)

nx.draw(G, with_labels=True, node_color=color_map, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
kg_df = pd.read_csv("ML_Diagram_2.csv")

# %%
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)

color_map = []
for node in G:
    if node == "Diabetes":
        color_map.append('orange')
    elif node == 165:
        color_map.append('orange')
    elif node == 106:
        color_map.append('orange')
    elif node == 279:
        color_map.append('orange')
    elif node == 151:
        color_map.append('orange')
    else: 
        color_map.append('skyblue')      

#nx.draw(G, node_color=color_map, with_labels=True)

nx.draw(G, with_labels=True, node_color=color_map, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
